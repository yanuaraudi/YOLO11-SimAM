# %%
from ultralytics import YOLO
model = YOLO('yolo11-cls-eca-resnet18.yaml')
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /home/stygia/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:13<00:00, 3.52MB/s]
# YOLO11-cls-eca-resnet18 summary: 59 layers, 11,186,760 parameters, 11,186,760 gradients

# %%
dataset = 'mosquito_dataset_cls/'

# %%
results = model.train(task='classify' ,data=dataset, epochs=500, patience=50, imgsz=320, batch=64)
