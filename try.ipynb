# %%
from ultralytics import YOLO
model = YOLO('yolo11-cls-eca-resnet18.yaml')
# Out:
# YOLO11-cls-eca-resnet18 summary: 59 layers, 11,186,760 parameters, 11,186,760 gradients

# %%
dataset = 'mosquito_dataset_cls/'

# %%
results = model.train(task='classify' ,data=dataset, epochs=500, patience=50, imgsz=124, batch=1)
# Out:
# New https://pypi.org/project/ultralytics/8.3.230 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.185 🚀 Python-3.10.12 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce GTX 1650, 3716MiB)
# ...
